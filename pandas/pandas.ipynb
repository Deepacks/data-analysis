# %%
import pandas as pd

# %% [markdown]
# # series = 1-dimensional

# %%
series = pd.Series(["BMW", "Toyota", "Honda"])

# %%
series
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: object
